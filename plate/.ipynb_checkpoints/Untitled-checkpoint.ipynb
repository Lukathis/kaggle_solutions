# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import train_test_split

# %%
# df_train = pd.read_csv('../plate/data/history2013_2017.csv')
df_train = pd.read_csv('../plate/data/history_with_warning.csv')

df_train = df_train
df_train
# Out:
#     time  time_weight  time_modified  total_num  last_month  warning  \
# 0      1          1.0            2.0       8000       37800    37800
# 1      2          1.0            3.0       7500       37800    38311
# 2      3          1.0            4.0       8000       38300    38466
# 3      4          1.0            5.0       8500       39600    38938
# 4      5          1.0            6.0       8500       41000    40046
# 5      6          1.0            7.0       9200       41900    41260
# 6      7          1.0            8.0       9000       39200    41426
# 7      8          1.0            9.0       9000       38400    40668
# 8      9          1.0           10.0       9000       39800    39970
# 9     10          1.0           11.0       9000       41800    40570
# 10    11          1.0           12.0       8500       43000    41873
# 11    12          1.0           13.0       9000       44900    43581
# 12    13          1.1           14.1       8000       10400    34844
# 13    14          1.1           15.1       7500       38300    33344
# 14    15          1.1           16.1       8000       44200    33123
# 15    16          1.1           17.1       8000       46200    43352
# 16    17          1.1           18.1       9000       46300    46228
# 17    18          1.1           19.1       9000       47400    47252
# 18    19          1.1           20.1       9000       48500    47985
# 19    20          1.1           21.1       9000       50900    49243
# 20    21          1.1           22.1       9500       51000    50752
# 21    22          1.1           23.1       9000       52200    52008
# 22    23          1.1           24.1       9000       53800    52953
# 23    24          1.1           25.1       8500       45700    51422
# 24    25          1.2           26.2       8000       51000    51027
# 25    26          1.2           27.2       8000       52800    50756
# 26    27          1.2           28.2       8000       55400    53421
# 27    28          1.2           29.2       8500       58300    55817
# 28    29          1.2           30.2       9300       61000    58628
# 29    30          1.2           31.2       9500       64000    61539
# ..   ...          ...            ...        ...         ...      ...
# 60    61          1.5           62.5       7653       74000    73845
# 61    62          1.5           63.5       7406       76500    74840
# 62    63          1.5           64.5       8288       74600    75221
# 63    64          1.5           65.5       7482       80600    77402
# 64    65          1.5           66.5       7441       79000    78229
# 65    66          1.5           67.5       7531       80000    79959
# 66    67          1.5           68.5       7454       83100    80763
# 67    68          1.5           69.5       8727       82600    81944
# 68    69          1.5           70.5       7763       82100    82662
# 69    70          1.5           71.5       7514       85300    83413
# 70    71          1.5           72.5       7698       84600    84100
# 71    72          1.5           73.5       9409       84500    84900
# 72    73          1.6           74.6       8363       82200    83876
# 73    74          1.6           75.6       8310       83200    83389
# 74    75          1.6           76.6      11829       83100    82915
# 75    76          1.6           77.6      11598       85100    83840
# 76    77          1.6           78.6      11546       85000    84444
# 77    78          1.6           79.6      11475       84400    84889
# 78    79          1.6           80.6      11549       87200    85592
# 79    80          1.6           81.6      12889       86900    86221
# 80    81          1.6           82.6      11621       86500    86901
# 81    82          1.6           83.6      11549       88300    87276
# 82    83          1.6           84.6      12261       88600    87849
# 83    84          1.6           85.6      12215       88300    88479
# 84    85          1.7           86.7      10157       87600    88254
# 85    86          1.7           87.7      10356       88200    88112
# 86    87          1.7           88.7      12196       87800    87947
# 87    88          1.7           89.7      10316       89800    88669
# 88    89          1.7           90.7      10312       90100    89325
# 89    90          1.7           91.7      10325       89400    89864
#
#     population  lowest  average
# 0        18975   37800    38311
# 1        18810   38300    38620
# 2        17704   39600    39882
# 3        17313   41000    41637
# 4        16324   41900    42262
# 5        16252   39200    40380
# 6        13389   38400    39362
# 7        16855   39800    40169
# 8        15198   41800    42180
# 9        14941   43000    43271
# 10       13429   44900    45291
# 11       11224   10400    15970
# 12       30675   38300    38771
# 13       25104   44200    44627
# 14       25014   46200    46657
# 15       22326   46300    47399
# 16       25708   47400    47700
# 17       22474   48500    48855
# 18       21852   50900    51174
# 19       21544   51000    52228
# 20       22268   52200    52622
# 21       19415   53800    54008
# 22       20050   45700    47635
# 23       26531   51000    51437
# 24       24354   52800    53195
# 25       23391   55400    55632
# 26       24897   58300    58625
# 27       22706   61000    61626
# 28       24230   64000    64367
# 29       24774   55800    58227
# ..         ...     ...      ...
# 60      103224   76500    76618
# 61      132690   74600    74830
# 62      152298   80600    80759
# 63      156007   79000    79099
# 64      172205   80000    80020
# 65      166302   83100    83171
# 66      166939   82600    82642
# 67      165765   82100    82172
# 68      170995   85300    85424
# 69      169159   84600    84703
# 70      179133   84500    84572
# 71      187533   82200    82352
# 72      196470   83200    83244
# 73      221109   83100    83148
# 74      256897   85100    85127
# 75      277889   85000    85058
# 76      275438   84400    84483
# 77      240750   87200    87235
# 78      251188   86900    86946
# 79      229544   86500    86523
# 80      213212   88300    88359
# 81      215424   88600    88665
# 82      219882   88300    88412
# 83      232101   87600    87685
# 84      251717   88200    88240
# 85      262010   87800    87916
# 86      252273   89800    89850
# 87      270197   90100    90209
# 88      244349   89400    89532
# 89      269189   92200    92250
#
# [90 rows x 9 columns]

# %%
corr = df_train[df_train.columns].corr()
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, cmap=cmap, annot=True)
plt.show()
# Out:
# /Users/Chi/.pyenv/versions/3.4.3/lib/python3.4/site-packages/seaborn/palettes.py:725: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   pal = _ColorPalette(pal(np.linspace(0, 1, n_colors)))
# /Users/Chi/.pyenv/versions/3.4.3/lib/python3.4/site-packages/seaborn/palettes.py:725: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   pal = _ColorPalette(pal(np.linspace(0, 1, n_colors)))
# /Users/Chi/.pyenv/versions/3.4.3/lib/python3.4/site-packages/seaborn/matrix.py:143: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if xticklabels == []:
# /Users/Chi/.pyenv/versions/3.4.3/lib/python3.4/site-packages/seaborn/matrix.py:151: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if yticklabels == []:

# %%
x_features = pd.DataFrame(data=df_train, columns=['time_modified', 'total_num', 'warning', 'population'])
x_features
# Out:
#     time  total_num  warning  population
# 0      1       8000    37800       18975
# 1      2       7500    38311       18810
# 2      3       8000    38466       17704
# 3      4       8500    38938       17313
# 4      5       8500    40046       16324
# 5      6       9200    41260       16252
# 6      7       9000    41426       13389
# 7      8       9000    40668       16855
# 8      9       9000    39970       15198
# 9     10       9000    40570       14941
# 10    11       8500    41873       13429
# 11    12       9000    43581       11224
# 12    13       8000    34844       30675
# 13    14       7500    33344       25104
# 14    15       8000    33123       25014
# 15    16       8000    43352       22326
# 16    17       9000    46228       25708
# 17    18       9000    47252       22474
# 18    19       9000    47985       21852
# 19    20       9000    49243       21544
# 20    21       9500    50752       22268
# 21    22       9000    52008       19415
# 22    23       9000    52953       20050
# 23    24       8500    51422       26531
# 24    25       8000    51027       24354
# 25    26       8000    50756       23391
# 26    27       8000    53421       24897
# 27    28       8500    55817       22706
# 28    29       9300    58628       24230
# 29    30       9500    61539       24774
# ..   ...        ...      ...         ...
# 60    61       7653    73845      103224
# 61    62       7406    74840      132690
# 62    63       8288    75221      152298
# 63    64       7482    77402      156007
# 64    65       7441    78229      172205
# 65    66       7531    79959      166302
# 66    67       7454    80763      166939
# 67    68       8727    81944      165765
# 68    69       7763    82662      170995
# 69    70       7514    83413      169159
# 70    71       7698    84100      179133
# 71    72       9409    84900      187533
# 72    73       8363    83876      196470
# 73    74       8310    83389      221109
# 74    75      11829    82915      256897
# 75    76      11598    83840      277889
# 76    77      11546    84444      275438
# 77    78      11475    84889      240750
# 78    79      11549    85592      251188
# 79    80      12889    86221      229544
# 80    81      11621    86901      213212
# 81    82      11549    87276      215424
# 82    83      12261    87849      219882
# 83    84      12215    88479      232101
# 84    85      10157    88254      251717
# 85    86      10356    88112      262010
# 86    87      12196    87947      252273
# 87    88      10316    88669      270197
# 88    89      10312    89325      244349
# 89    90      10325    89864      269189
#
# [90 rows x 4 columns]

# %%
y = df_train.iloc[:,8]
y.head(4)
# Out:
# 0    38311
# 1    38620
# 2    39882
# 3    41637
# Name: average, dtype: int64

# %% [markdown]
# # Standard scaling

# %%
scaler = StandardScaler()
x_features = scaler.fit_transform(x_features)
x_features
# Out:
# array([[ -1.71291154e+00,  -7.14332620e-01,  -1.70014686e+00,
#          -8.56114719e-01],
#        [ -1.67441914e+00,  -1.07849902e+00,  -1.67090167e+00,
#          -8.57954441e-01],
#        [ -1.63592675e+00,  -7.14332620e-01,  -1.66203082e+00,
#          -8.70286153e-01],
#        [ -1.59743435e+00,  -3.50166222e-01,  -1.63501766e+00,
#          -8.74645737e-01],
#        [ -1.55894196e+00,  -3.50166222e-01,  -1.57160539e+00,
#          -8.85672920e-01],
#        [ -1.52044957e+00,   1.59666734e-01,  -1.50212662e+00,
#          -8.86475707e-01],
#        [ -1.48195717e+00,   1.40001748e-02,  -1.49262622e+00,
#          -9.18397672e-01],
#        [ -1.44346478e+00,   1.40001748e-02,  -1.53600754e+00,
#          -8.79752360e-01],
#        [ -1.40497238e+00,   1.40001748e-02,  -1.57595497e+00,
#          -8.98227629e-01],
#        [ -1.36647999e+00,   1.40001748e-02,  -1.54161620e+00,
#          -9.01093135e-01],
#        [ -1.32798760e+00,  -3.50166222e-01,  -1.46704384e+00,
#          -9.17951679e-01],
#        [ -1.28949520e+00,   1.40001748e-02,  -1.36929281e+00,
#          -9.42537056e-01],
#        [ -1.25100281e+00,  -7.14332620e-01,  -1.86932253e+00,
#          -7.25661700e-01],
#        [ -1.21251041e+00,  -1.07849902e+00,  -1.95516946e+00,
#          -7.87777407e-01],
#        [ -1.17401802e+00,  -7.14332620e-01,  -1.96781757e+00,
#          -7.88780892e-01],
#        [ -1.13552563e+00,  -7.14332620e-01,  -1.38239877e+00,
#          -8.18751636e-01],
#        [ -1.09703323e+00,   1.40001748e-02,  -1.21780160e+00,
#          -7.81042909e-01],
#        [ -1.05854084e+00,   1.40001748e-02,  -1.15919676e+00,
#          -8.17101461e-01],
#        [ -1.02004844e+00,   1.40001748e-02,  -1.11724623e+00,
#          -8.24036656e-01],
#        [ -9.81556049e-01,   1.40001748e-02,  -1.04524928e+00,
#          -8.27470804e-01],
#        [  1.67441914e+00,   9.69572801e-01,   1.24869504e+00,
#           1.65676721e+00],
#        [  1.71291154e+00,   9.79041127e-01,   1.27954271e+00,
#           1.93372900e+00]])

# %%
latest = -2
x_train, x_test, y_train, y_test = train_test_split(x_features[:latest], y[:latest], 
            test_size=0.25, random_state=33)
x7 = x_features[latest:]
y7 = y[latest:]
(x7, y7)
# Out:
# (array([[ 1.67441914,  0.9695728 ,  1.24869504,  1.65676721],
#         [ 1.71291154,  0.97904113,  1.27954271,  1.933729  ]]), 88    89532
#  89    92250
#  Name: average, dtype: int64)

# %% [markdown]
# # Models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression  
from sklearn.linear_model import Ridge
from sklearn.ensemble     import GradientBoostingRegressor
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import BayesianRidge

models = []

models.append(('LinearRegressor : ', LinearRegression()))
# models.append(('Logistic        : ', LogisticRegression()))
models.append(('Ridge           : ', Ridge()))
models.append(('GradientBoosting: ', GradientBoostingRegressor()))
models.append(('ARDRegression   : ', ARDRegression()))
models.append(('BayesianRidge   : ', BayesianRidge()))

print('Models appended...')
# Out:
# Models appended...

# %% [markdown]
# # Results

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import r2_score

results = []
names = []
for name, model in models:
    model.fit(x_train, y_train)
    y_predict = model.predict(x_test)
    
    # evaluate
    print(name, end='--')
    print(r2_score(y_test, y_predict), end='--')
    y7_predict = model.predict(x7)
    y7_predict = list(map(lambda i: int(i), y7_predict))
    print(y7_predict)
    results.append(y7_predict)

print('---------average---------')
def add(a, b):
    for i in range(len(a)):
        a[i] += b[i]
        
map(add, results)

average = results[0]

for i in range(len(results) - 1):
    for j in range(len(average)):
        average[j] += results[i + 1][j]
average = list(map(lambda d: int(d / len(results)), average))
        
print(average)
print('---------reality---------')
print(y7)
# Out:
# LinearRegressor : --0.980535447223--[91217, 90639]
# Ridge           : --0.983017502677--[91068, 90815]
# GradientBoosting: --0.988823979609--[88910, 88910]
# ARDRegression   : --0.979970419407--[90103, 90626]
# BayesianRidge   : --0.982170241264--[91105, 90732]
# ---------average---------
# [90480, 90344]
# ---------reality---------
# 88    89532
# 89    92250
# Name: average, dtype: int64

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb

# transform
x_valid = x_test
y_valid = y_test
x_test = x7

d_train = xgb.DMatrix(x_train, label=y_train)
d_valid = xgb.DMatrix(x_valid, label=y_valid)
d_test = xgb.DMatrix(x_test)

params = {}
params['objective'] = 'reg:linear'
params['eta'] = 0.02
params['max_depth'] = 4

def xgb_r2_score(preds, dtrain):
    labels = dtrain.get_label()
    return 'r2', r2_score(labels, preds)

watchlist = [(d_train, 'train'), (d_valid, 'valid')]

clf = xgb.train(params, d_train, 1000, watchlist, early_stopping_rounds=50, feval=xgb_r2_score, maximize=True, verbose_eval=10)

p_test = clf.predict(d_test)

sub = pd.DataFrame()
sub['y'] = p_test
sub.head()
print(p_test)
print('---------reality---------')
print(y7)
# Out:
# [0]	train-rmse:67991	valid-rmse:71938.4	train-r2:-14.1188	valid-r2:-17.6827
# Multiple eval metrics have been passed: 'valid-r2' will be used for early stopping.
#
# Will train until valid-r2 hasn't improved in 50 rounds.
# [10]	train-rmse:55996.5	valid-rmse:59217.8	train-r2:-9.255	valid-r2:-11.6597
# [20]	train-rmse:46158	valid-rmse:48773.6	train-r2:-5.96798	valid-r2:-7.58793
# [30]	train-rmse:38084	valid-rmse:40265.7	train-r2:-3.7435	valid-r2:-4.85315
# [40]	train-rmse:31456.9	valid-rmse:33327.9	train-r2:-2.23628	valid-r2:-3.00991
# [50]	train-rmse:26025	valid-rmse:27615.7	train-r2:-1.2151	valid-r2:-1.75315
# [60]	train-rmse:21568.7	valid-rmse:22866.6	train-r2:-0.521467	valid-r2:-0.887649
# [70]	train-rmse:17906.2	valid-rmse:18927.9	train-r2:-0.048623	valid-r2:-0.293373
# [80]	train-rmse:14892.8	valid-rmse:15738	train-r2:0.274624	valid-r2:0.105837
# [90]	train-rmse:12408	valid-rmse:13027	train-r2:0.496481	valid-r2:0.387362
# [100]	train-rmse:10373.2	valid-rmse:10817.2	train-r2:0.648084	valid-r2:0.577576
# [110]	train-rmse:8708.11	valid-rmse:9001.03	train-r2:0.751994	valid-r2:0.707516
# [120]	train-rmse:7346.81	valid-rmse:7537.82	train-r2:0.823473	valid-r2:0.794879
# [130]	train-rmse:6226.09	valid-rmse:6356.92	train-r2:0.873222	valid-r2:0.854115
# [140]	train-rmse:5292.06	valid-rmse:5404.03	train-r2:0.908407	valid-r2:0.894572
# [150]	train-rmse:4519.54	valid-rmse:4609.22	train-r2:0.933196	valid-r2:0.923304
# [160]	train-rmse:3880.19	valid-rmse:3989.53	train-r2:0.95076	valid-r2:0.942541
# [170]	train-rmse:3348.12	valid-rmse:3554.88	train-r2:0.963338	valid-r2:0.954379
# [180]	train-rmse:2913.21	valid-rmse:3206.77	train-r2:0.972244	valid-r2:0.962876
# [190]	train-rmse:2548.9	valid-rmse:2930.68	train-r2:0.978752	valid-r2:0.968993
# [200]	train-rmse:2240.11	valid-rmse:2728.18	train-r2:0.983588	valid-r2:0.97313
# [210]	train-rmse:1986.02	valid-rmse:2586.09	train-r2:0.9871	valid-r2:0.975856
# [220]	train-rmse:1774.77	valid-rmse:2479.39	train-r2:0.989699	valid-r2:0.977808
# [230]	train-rmse:1597.56	valid-rmse:2367.61	train-r2:0.991653	valid-r2:0.979763
# [240]	train-rmse:1442.69	valid-rmse:2287.26	train-r2:0.993193	valid-r2:0.981114
# [250]	train-rmse:1311.04	valid-rmse:2238.13	train-r2:0.994379	valid-r2:0.981916
# [260]	train-rmse:1197.38	valid-rmse:2199.51	train-r2:0.995311	valid-r2:0.982535
# [270]	train-rmse:1102.53	valid-rmse:2171.25	train-r2:0.996024	valid-r2:0.982981
# [280]	train-rmse:1013.78	valid-rmse:2129.85	train-r2:0.996639	valid-r2:0.983624
# [290]	train-rmse:933.671	valid-rmse:2096.59	train-r2:0.997149	valid-r2:0.984131
# [300]	train-rmse:869.592	valid-rmse:2076.08	train-r2:0.997527	valid-r2:0.98444
# [310]	train-rmse:808.26	valid-rmse:2053.41	train-r2:0.997863	valid-r2:0.984778
# [320]	train-rmse:769.109	valid-rmse:2029.07	train-r2:0.998065	valid-r2:0.985137
# [330]	train-rmse:742.343	valid-rmse:2015.6	train-r2:0.998198	valid-r2:0.985333
# [340]	train-rmse:704.171	valid-rmse:2004.15	train-r2:0.998378	valid-r2:0.9855
# [350]	train-rmse:674.061	valid-rmse:1991.93	train-r2:0.998514	valid-r2:0.985676
# [360]	train-rmse:649.292	valid-rmse:1985.13	train-r2:0.998621	valid-r2:0.985774
# [370]	train-rmse:623.126	valid-rmse:1978.69	train-r2:0.99873	valid-r2:0.985866
# [380]	train-rmse:598.092	valid-rmse:1974.09	train-r2:0.99883	valid-r2:0.985931
# [390]	train-rmse:577.657	valid-rmse:1972.64	train-r2:0.998909	valid-r2:0.985952
# [400]	train-rmse:554.672	valid-rmse:1969.23	train-r2:0.998994	valid-r2:0.986
# [410]	train-rmse:534.313	valid-rmse:1966.46	train-r2:0.999066	valid-r2:0.98604
# [420]	train-rmse:516.871	valid-rmse:1965.01	train-r2:0.999126	valid-r2:0.98606
# [430]	train-rmse:500.756	valid-rmse:1962.32	train-r2:0.99918	valid-r2:0.986099
# [440]	train-rmse:483.343	valid-rmse:1959.55	train-r2:0.999236	valid-r2:0.986138
# [450]	train-rmse:469.386	valid-rmse:1956	train-r2:0.999279	valid-r2:0.986188
# [460]	train-rmse:454.27	valid-rmse:1954.91	train-r2:0.999325	valid-r2:0.986203
# [470]	train-rmse:437.426	valid-rmse:1953.01	train-r2:0.999374	valid-r2:0.98623
# [480]	train-rmse:423.317	valid-rmse:1951.27	train-r2:0.999414	valid-r2:0.986255
# [490]	train-rmse:410.344	valid-rmse:1948.1	train-r2:0.999449	valid-r2:0.986299
# [500]	train-rmse:396.67	valid-rmse:1946.06	train-r2:0.999485	valid-r2:0.986328
# [510]	train-rmse:381.227	valid-rmse:1942.22	train-r2:0.999525	valid-r2:0.986382
# [520]	train-rmse:369.08	valid-rmse:1936.76	train-r2:0.999554	valid-r2:0.986458
# [530]	train-rmse:355.118	valid-rmse:1933.07	train-r2:0.999588	valid-r2:0.98651
# [540]	train-rmse:340.871	valid-rmse:1928.38	train-r2:0.99962	valid-r2:0.986575
# [550]	train-rmse:330.465	valid-rmse:1926.35	train-r2:0.999643	valid-r2:0.986604
# [560]	train-rmse:315.071	valid-rmse:1921.97	train-r2:0.999675	valid-r2:0.986664
# [570]	train-rmse:303.708	valid-rmse:1919.71	train-r2:0.999698	valid-r2:0.986696
# [580]	train-rmse:292.957	valid-rmse:1916.1	train-r2:0.999719	valid-r2:0.986746
# [590]	train-rmse:281.891	valid-rmse:1912.69	train-r2:0.99974	valid-r2:0.986793
# [600]	train-rmse:275.036	valid-rmse:1909.41	train-r2:0.999753	valid-r2:0.986838
# [610]	train-rmse:265.491	valid-rmse:1905.74	train-r2:0.999769	valid-r2:0.986889
# [620]	train-rmse:256.536	valid-rmse:1902	train-r2:0.999785	valid-r2:0.98694
# [630]	train-rmse:248.568	valid-rmse:1899.5	train-r2:0.999798	valid-r2:0.986974
# [640]	train-rmse:239.999	valid-rmse:1897.53	train-r2:0.999812	valid-r2:0.987001
# [650]	train-rmse:232.2	valid-rmse:1895.03	train-r2:0.999824	valid-r2:0.987036
# [660]	train-rmse:225.083	valid-rmse:1893.53	train-r2:0.999834	valid-r2:0.987056
# [670]	train-rmse:214.568	valid-rmse:1892.15	train-r2:0.999849	valid-r2:0.987075
# [680]	train-rmse:205.667	valid-rmse:1890.09	train-r2:0.999862	valid-r2:0.987103
# [690]	train-rmse:200.394	valid-rmse:1888.4	train-r2:0.999869	valid-r2:0.987126
# [700]	train-rmse:195.462	valid-rmse:1886.98	train-r2:0.999875	valid-r2:0.987146
# [710]	train-rmse:188.331	valid-rmse:1885.22	train-r2:0.999884	valid-r2:0.98717
# [720]	train-rmse:181.121	valid-rmse:1882.21	train-r2:0.999893	valid-r2:0.987211
# [730]	train-rmse:174.217	valid-rmse:1880.25	train-r2:0.999901	valid-r2:0.987237
# [740]	train-rmse:170.296	valid-rmse:1880.71	train-r2:0.999905	valid-r2:0.987231
# [750]	train-rmse:165.322	valid-rmse:1880.51	train-r2:0.999911	valid-r2:0.987234
# [760]	train-rmse:160.578	valid-rmse:1880.56	train-r2:0.999916	valid-r2:0.987233
# [770]	train-rmse:154.574	valid-rmse:1879.93	train-r2:0.999922	valid-r2:0.987242
# [780]	train-rmse:149.681	valid-rmse:1878.98	train-r2:0.999927	valid-r2:0.987254
# [790]	train-rmse:144.933	valid-rmse:1879.06	train-r2:0.999931	valid-r2:0.987253
# [800]	train-rmse:141.203	valid-rmse:1878.79	train-r2:0.999935	valid-r2:0.987257
# [810]	train-rmse:135.663	valid-rmse:1877.97	train-r2:0.99994	valid-r2:0.987268
# [820]	train-rmse:132.056	valid-rmse:1878.15	train-r2:0.999943	valid-r2:0.987266
# [830]	train-rmse:129.022	valid-rmse:1878.59	train-r2:0.999946	valid-r2:0.98726
# [840]	train-rmse:126.365	valid-rmse:1878.29	train-r2:0.999948	valid-r2:0.987264
# [850]	train-rmse:123.73	valid-rmse:1877.87	train-r2:0.99995	valid-r2:0.987269
# [860]	train-rmse:121.536	valid-rmse:1877.24	train-r2:0.999952	valid-r2:0.987278
# [870]	train-rmse:117.795	valid-rmse:1877.34	train-r2:0.999955	valid-r2:0.987277
# [880]	train-rmse:113.867	valid-rmse:1876.97	train-r2:0.999958	valid-r2:0.987282
# [890]	train-rmse:110.265	valid-rmse:1876.75	train-r2:0.99996	valid-r2:0.987285
# [900]	train-rmse:107.162	valid-rmse:1876.65	train-r2:0.999962	valid-r2:0.987286
# [910]	train-rmse:104.528	valid-rmse:1876.33	train-r2:0.999964	valid-r2:0.98729
# [920]	train-rmse:101.316	valid-rmse:1875.79	train-r2:0.999966	valid-r2:0.987298
# [930]	train-rmse:98.2015	valid-rmse:1876.04	train-r2:0.999968	valid-r2:0.987294
# [940]	train-rmse:95.4809	valid-rmse:1875.96	train-r2:0.99997	valid-r2:0.987295
# [950]	train-rmse:92.7687	valid-rmse:1876.34	train-r2:0.999972	valid-r2:0.98729
# [960]	train-rmse:88.3226	valid-rmse:1875.23	train-r2:0.999974	valid-r2:0.987305
# [970]	train-rmse:85.1929	valid-rmse:1874.12	train-r2:0.999976	valid-r2:0.98732
# [980]	train-rmse:82.843	valid-rmse:1874	train-r2:0.999978	valid-r2:0.987322
# [990]	train-rmse:80.7956	valid-rmse:1873.88	train-r2:0.999979	valid-r2:0.987323
# [999]	train-rmse:78.745	valid-rmse:1873.74	train-r2:0.99998	valid-r2:0.987325
# [ 88926.625  88870.625]
# ---------reality---------
# 88    89532
# 89    92250
# Name: average, dtype: int64
